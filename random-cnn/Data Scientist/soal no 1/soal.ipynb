# %%
import pandas as pd

df_covid = pd.read_csv("./covid-19-data.csv", delimiter=";")
df_country = pd.read_csv("./country-index.csv", delimiter=";")

# %%
df = pd.merge(df_covid, df_country, on = ['CODE', 'DATE'], how="inner")
df
# Out:
#       CODE      COUNTRY        DATE  total case  total death  \
# 0      AFG  Afghanistan  31/12/2019    0.000000     0.000000
# 1      AFG  Afghanistan  01/01/2020    0.000000     0.000000
# 2      AFG  Afghanistan  02/01/2020    0.000000     0.000000
# 3      AFG  Afghanistan  03/01/2020    0.000000     0.000000
# 4      AFG  Afghanistan  04/01/2020    0.000000     0.000000
# ...    ...          ...         ...         ...          ...
# 50428  ZWE     Zimbabwe  15/10/2020    8.994048     5.442418
# 50429  ZWE     Zimbabwe  16/10/2020    8.996528     5.442418
# 50430  ZWE     Zimbabwe  17/10/2020    8.999496     5.442418
# 50431  ZWE     Zimbabwe  18/10/2020    9.000853     5.442418
# 50432  ZWE     Zimbabwe  19/10/2020    9.005405     5.442418
#
#        stringency index  population  GDP PER capita  human development indeks
# 0              0.000000   17.477233        7.497754                     0.498
# ...

# %%
df =
