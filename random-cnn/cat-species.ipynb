# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        (os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Rescaling
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# 2024-05-10 02:49:36.500726: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-10 02:49:36.500818: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-10 02:49:36.626443: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
dataset_path = '/kaggle/input/felidae-tiger-lion-cheetah-leopard-puma/Felidae'

# %%
from pathlib import Path
from collections import Counter

dataset_path = Path(dataset_path)

# %%
paths = list(dataset_path.glob('*/*'))
classes = dict(Counter([path.parent.stem for path in paths]))
extensions = dict(Counter([path.suffix for path in paths]))
classes, extensions
# Out:
# ({'Cheetah': 56, 'Lion': 49, 'Tiger': 48, 'Puma': 40, 'Leopard': 50},
#  {'.jpg': 243})

# %%
# check dataset for non-jpg even though they have .jpg extension files:
from PIL import Image

formats = []
for path in paths:
    im = Image.open(path)
    formats.append(im.format)
    im.close()
    
Counter(formats)
# Out:
# Counter({'JPEG': 180, 'WEBP': 61, 'PNG': 2})

# %%
# tensorflow cannot handle webp images
# converting webp and png to jpg

new_ds_path = Path('./NewDataset')
new_ds_path.mkdir(parents=True, exist_ok=True)
for c in classes:
    class_path = new_ds_path / c
    class_path.mkdir(parents=True, exist_ok=True)

# %%
# !tree
# Out:
# .
# |-- NewDataset
# |   |-- Cheetah
# |   |-- Leopard
# |   |-- Lion
# |   |-- Puma
# |   `-- Tiger
# `-- __notebook__.ipynb
#
# 6 directories, 1 file

# %%
for path in paths:
    im = Image.open(path)
    im = im.convert(mode='RGB')
    class_name = path.parent.stem
    file_name = path.stem
    fp = new_ds_path.joinpath(class_name).joinpath(file_name)
    fp = fp.parent / (fp.name + '.jpg')
#     print(fp)
    im.save(fp, format='JPEG')

# %%
class Config:
    batch_size = 16
    img_dim = (224,224)
    epochs = 20

# %%
dataset_path = Path('./NewDataset')

# %%
train_ds = keras.utils.image_dataset_from_directory(dataset_path,
                                                    subset = 'training',
                                                    validation_split = 0.2,
                                                    image_size = Config.img_dim,
                                                    batch_size = Config.batch_size,
                                                    seed=1
                                                   )

val_ds = keras.utils.image_dataset_from_directory(dataset_path,
                                                  subset = 'validation',
                                                  validation_split = 0.2,
                                                  image_size = Config.img_dim, 
                                                  batch_size = Config.batch_size,
                                                  seed=1
                                                 )
# Out:
# Found 243 files belonging to 5 classes.
# Using 195 files for training.
# Found 243 files belonging to 5 classes.
# Using 48 files for validation.

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal", input_shape=(*Config.img_dim, 3)),
    layers.RandomContrast(0.2),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.3)
  ]
)
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/preprocessing/tf_data_layer.py:18: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model = Sequential([
    Rescaling(1./255,  input_shape=(*Config.img_dim, 3)),
    Conv2D(16, 3, activation='relu',),
    MaxPooling2D(),
    Conv2D(32, 3, activation='relu'),
    MaxPooling2D(),
    Conv2D(128, 3, activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(5)
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 222, 222, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        36,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    88,605,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 5)              │            85 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params:
# Epoch 22/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3455 - loss: 1.4768 - val_accuracy: 0.4167 - val_loss: 1.3790
# Epoch 23/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.3011 - loss: 1.3869 - val_accuracy: 0.1875 - val_loss: 1.7501
# Epoch 24/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3454 - loss: 1.6583 - val_accuracy: 0.2500 - val_loss: 1.5443
# Epoch 25/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3236 - loss: 1.4613 - val_accuracy: 0.1667 - val_loss: 1.8060
# Epoch 26/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3149 - loss: 1.4087 - val_accuracy: 0.2917 - val_loss: 1.4561
# Epoch 27/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.4025 - loss: 1.2769 - val_accuracy: 0.2292 - val_loss: 1.4835
# Epoch 28/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.2720 - loss: 1.4993 - val_accuracy: 0.2708 - val_loss: 1.5804
# Epoch 29/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.2908 - loss: 1.4476 - val_accuracy: 0.1875 - val_loss: 1.6174
# Epoch 30/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.3918 - loss: 1.3612 - val_accuracy: 0.3333 - val_loss: 1.4333
# Epoch 31/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.5036 - loss: 1.1844 - val_accuracy: 0.3958 - val_loss: 1.3675
# Epoch 32/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.4653 - loss: 1.1623 - val_accuracy: 0.1875 - val_loss: 1.8653
# Epoch 33/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.3181 - loss: 1.4624 - val_accuracy: 0.5000 - val_loss: 1.3175
# Epoch 34/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.4966 - loss: 1.1381 - val_accuracy: 0.3333 - val_loss: 1.3010
# Epoch 35/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.4281 - loss: 1.1998 - val_accuracy: 0.2083 - val_loss: 1.4076
# Epoch 36/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5232 - loss: 1.2192 - val_accuracy: 0.3125 - val_loss: 1.6003
# Epoch 37/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5035 - loss: 1.0864 - val_accuracy: 0.2083 - val_loss: 1.6947
# Epoch 38/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5729 - loss: 0.9879 - val_accuracy: 0.2500 - val_loss: 1.3763
# Epoch 39/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.5915 - loss: 0.9746 - val_accuracy: 0.2708 - val_loss: 1.7763
# Epoch 40/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.4403 - loss: 1.2693 - val_accuracy: 0.3333 - val_loss: 1.5604
# Epoch 41/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.4911 - loss: 1.1697 - val_accuracy: 0.2500 - val_loss: 1.4606
# Epoch 42/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5635 - loss: 1.0315 - val_accuracy: 0.4167 - val_loss: 2.1350
# Epoch 43/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.5881 - loss: 1.0104 - val_accuracy: 0.4583 - val_loss: 1.5088
# Epoch 44/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.5403 - loss: 1.0223 - val_accuracy: 0.3125 - val_loss: 1.6166
# Epoch 45/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6227 - loss: 0.8882 - val_accuracy: 0.3333 - val_loss: 1.5935
# Epoch 46/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.6653 - loss: 0.8298 - val_accuracy: 0.3750 - val_loss: 1.4339
# Epoch 47/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.6003 - loss: 0.9448 - val_accuracy: 0.2917 - val_loss: 1.4133
# Epoch 48/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.7178 - loss: 0.8415 - val_accuracy: 0.4375 - val_loss: 1.3316
# Epoch 49/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.7266 - loss: 0.6804 - val_accuracy: 0.3125 - val_loss: 1.9391
# Epoch 50/50
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - accuracy: 0.7225 - loss: 0.6547 - val_accuracy: 0.2708 - val_loss: 1.9533

# %%
def plot_loss_curves(history):

  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["accuracy"]
  val_accuracy = history.history["val_accuracy"]

  epochs = range(len(history.history["loss"]))

  #plot loss
  plt.plot(epochs, loss, label = "training_loss")
  plt.plot(epochs, val_loss, label = "val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()

  #plot accuracy
  plt.figure() 
  plt.plot(epochs, accuracy, label = "training_accuracy")
  plt.plot(epochs, val_accuracy, label = "val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_loss_curves(history)
