# %%
from deepface import DeepFace
result = DeepFace.represent(img_path="dataset/ario/1.jpg", model_name="Facenet", enforce_detection=False)
print(result[0]["embedding"][:5])
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from '/Users/ariopurba37/miniforge3/envs/ai/lib/python3.10/site-packages/typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.
